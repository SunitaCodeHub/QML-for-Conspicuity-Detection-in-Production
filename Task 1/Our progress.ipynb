# %% [markdown]
# ## TEAM NAME: QUANTUM ENTANGLERS
#
# ### Team Members
#
# **Rajana Rama Satya Sai Durga Prasad**
# **Enrollment ID:** WQ24-UkA0PEQyOfbIQTn
# **Email:** rajanasatyasai@gmail.com
#
# **Sunita**
# **Enrollment ID:** WQ24-kntLxdjlEEqKqC9
# **Email:** khothsunita1508@gmail.com
#
# ### Project: QML-for-Conspicuity-Detection-in-Production

# %% [markdown]
# # **Task 1 conclusion**
#
#
# After exploring the various codebooks, we found the materials provided by Pennylane to be quite impressive. We thoroughly enjoyed most of the content and are actively engaging with the different sections of the Pennylane codebooks. The tasks are particularly interesting and engaging. However, we would appreciate future notebooks that focus more on solving machine learning tasks. While the demos are beneficial, constructing and solving these modules would significantly enhance our understanding of the technologies and make the material more accessible to a broader audience.
#
# ## Our Progress with the Codebooks
#
# - **Introduction to Quantum Computing**: This section provided a comprehensive overview of quantum computing principles, including the basics of quantum mechanics and the differences between classical and quantum computing. It set a solid foundation for understanding more complex concepts.
#
# - **Single Qubit Gates**: We learned about the fundamental building blocks of quantum circuits. This section covered various single qubit gates such as the Pauli-X, Pauli-Y, and Pauli-Z gates, as well as the Hadamard and phase gates. These gates are essential for manipulating qubits and forming the basis of quantum algorithms.
#
# - **Circuits with Many Qubits**: This part delved into constructing and understanding circuits involving multiple qubits. We explored entanglement, superposition, and how multi-qubit gates like the CNOT gate work. This section was crucial for understanding how complex quantum operations are performed and how qubits interact within a circuit.
#
# Overall, the Pennylane codebooks have been an invaluable resource in our journey to understand quantum computing. We look forward to more advanced modules, especially those focusing on practical machine learning applications, to further deepen our knowledge and skills.

# %% [markdown]
# ## **Rajana Rama Satya Sai Durga Prasad**

# %% [markdown]
# ![image.png](attachment:5eed9fcd-19a0-4c93-9e18-3b0a4909403a.png)

# %% [markdown]
# ![image.png](attachment:1430dbd8-3a62-4448-87f4-670afcd23f22.png)

# %% [markdown]
# ## **Sunita**

# %% [markdown]
# ![image.png](attachment:3fe6caee-b875-43d9-90aa-627ea3478b28.png)

# %% [markdown]
# ![image.png](attachment:198e1f9f-fbcd-4eaa-997b-30487ec26d84.png)
